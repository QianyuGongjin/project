# %% [markdown]
# <a href="https://colab.research.google.com/github/QianyuGongjin/project/blob/main/notebooks/how-to-auto-train-yolov8-model-with-autodistill.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# [![Roboflow Notebooks](https://media.roboflow.com/notebooks/template/bannertest2-2.png?ik-sdk-version=javascript-1.4.3&updatedAt=1672932710194)](https://github.com/roboflow/notebooks)
#
# # How to Auto Train YOLOv8 Model with Autodistill
#
# Autodistill uses big, slower foundation models to train small, faster supervised models. Using `autodistill`, you can go from unlabeled images to inference on a custom model running at the edge with no human intervention in between.
#
# ![Autodistill Steps](https://media.roboflow.com/open-source/autodistill/steps.jpg)
#
# As foundation models get better and better they will increasingly be able to augment or replace humans in the labeling process. We need tools for steering, utilizing, and comparing these models. Additionally, these foundation models are big, expensive, and often gated behind private APIs. For many production use-cases, we need models that can run cheaply and in realtime at the edge.
#
# ![Autodistill Connections](https://media.roboflow.com/open-source/autodistill/connections.jpg)
#
# ## Steps in this Tutorial
#
# In this tutorial, we are going to cover:
#
# - Before you start
# - Image dataset preperation
# - Autolabel dataset
# - Train target model
# - Evaluate target model
# - Run video inference
# - Upload dataset and model to Roboflow (coming soon)
#
# ## 🔥 Let's begin!

# %% [markdown]
# ## ⚡ Before you start
#
# Let's make sure that we have access to GPU. We can use `nvidia-smi` command to do that. In case of any problems navigate to `Edit` -> `Notebook settings` -> `Hardware accelerator`, set it to `GPU`, and then click `Save`.

# %%
# !nvidia-smi
# Out:
# Wed Jan  1 07:47:12 2025
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   54C    P8              10W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+

# %% [markdown]
# ## 🧪 Install autodistill
#
# **NOTE:** Autodistill is an ecosystem for using big, slower foundation models to train small, faster supervised models. Each Base, as well as the Target model, has its own separate repository and pip package.

# %%
# !pip install -q \
  autodistill \
  autodistill-grounded-sam \
  autodistill-yolov8 \
  roboflow \
  supervision==0.24.0
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.8/46.8 kB 4.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.2/158.2 kB 9.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 527.0/527.0 kB 31.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.5/81.5 kB 8.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 7.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.1/93.1 kB 10.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 256.2/256.2 kB 25.2 MB/s eta 0:00:00

# %% [markdown]
# **NOTE:** To make it easier for us to manage datasets, images and models we create a `HOME` constant.

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %% [markdown]
# ## 🖼️ Image dataset preperation
#
# **NOTE:** To use Autodistill all you need to have is a folder of images that you want to automatically annotate, and use for target model training.

# %%
# !mkdir {HOME}/images

# %% [markdown]
# ## Download Images
#
# Below, we provide two methods of retrieving images for use with Autodistill:
#
# 1. Download a dataset with images from Roboflow, and;
# 2. Download a raw video and split it up into images.
#
# For this guide, we will be using a raw video to train our model.

# %% [markdown]
# ### Download Images from Roboflow
#
# You can download datasets from Roboflow using the below lines of code. You can download datasets associated with your account, or any of the 200,000+ public datasets on [Roboflow Universe](https://universe.roboflow.com/). To download a dataset from Roboflow, you will need a [free Roboflow account](https://app.roboflow.com).
#
# You need to paste in a URL to a full model, like so:
#
# ```
# https://universe.roboflow.com/mohamed-traore-2ekkp/taco-trash-annotations-in-context/model/16
# ```
#
# To find a model URL, go to a dataset page on Universe (i.e. the [TACO dataset](https://universe.roboflow.com/mohamed-traore-2ekkp/taco-trash-annotations-in-context/)), then click "Model" in the sidebar to view the latest model version. Copy the page URL, then paste it into the `download_dataset()` function below.
#
# ![Universe model link](https://media.roboflow.com/universe_deploy_tab.png)
#
# Uncomment the lines of code below to use the Roboflow dataset upload.

# %%
# import roboflow

# roboflow.login()

# dataset = roboflow.download_dataset(dataset_url="https://universe.roboflow.com/mohamed-traore-2ekkp/taco-trash-annotations-in-context/model/16", model_format="yolov8")
# Out:
# visit https://app.roboflow.com/auth-cli to get your authentication token.
# Paste the authentication token here: ··········
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in TACO:-Trash-Annotations-in-Context-Dataset-16 to yolov8:: 100%|██████████| 332390/332390 [00:06<00:00, 48314.78it/s]
# Extracting Dataset Version Zip to TACO:-Trash-Annotations-in-Context-Dataset-16 in yolov8:: 100%|██████████| 7204/7204 [00:01<00:00, 5532.14it/s]

# %% [markdown]
# Once you have downloaded your dataset, move all of the images from the `train` set in your downloaded dataset into the `images/` directory we created earlier:

# %%
# %mv {dataset.location}/train/* {HOME}/images
# Out:
# mv: cannot stat '{dataset.location}/train/*': No such file or directory

# %% [markdown]
# Now we are ready to start using Autodistill!

# %% [markdown]
# ### Download raw videos
#
# **NOTE:** In this tutorial, we will start with a directory containing video files and I will show you how to turn it into a ready-to-use collection of images. If you are working with your images, you can skip this part.

# %%
# !mkdir {HOME}/videos
# %cd {HOME}/videos

# download zip file containing videos
# !wget https://media.roboflow.com/milk.zip

# unzip videos
# !unzip milk.zip
# Out:
# /content/videos
# --2025-01-01 07:48:05--  https://media.roboflow.com/milk.zip
# Resolving media.roboflow.com (media.roboflow.com)... 34.110.133.209
# Connecting to media.roboflow.com (media.roboflow.com)|34.110.133.209|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1192719976 (1.1G) [application/zip]
# Saving to: ‘milk.zip’
#
# milk.zip            100%[===================>]   1.11G  54.2MB/s    in 20s
#
# 2025-01-01 07:48:25 (56.3 MB/s) - ‘milk.zip’ saved [1192719976/1192719976]
#
# Archive:  milk.zip
#   inflating: milk-video-1.mov
#   inflating: milk-video-2.mov
#   inflating: milk-video-3.mov
#   inflating: milk-video-4.mov
#   inflating: milk-video-5.mov
#   inflating: milk-video-6.mov
#   inflating: milk-video-7.mov
#   inflating: milk-video-8.mov

# %% [markdown]
# ### Convert videos into images
#
# **NOTE:** Now, let's convert videos into images. By default, the code below saves every `10th` frame from each video. You can change this by manipulating the value of the `FRAME_STRIDE` parameter.

# %%
VIDEO_DIR_PATH = f"{HOME}/videos"
IMAGE_DIR_PATH = f"{HOME}/images"
FRAME_STRIDE = 10

# %% [markdown]
# **NOTE:** Notice that we put two of our videos aside so that we can use them at the end of the notebook to evaluate our model.

# %%
import supervision as sv
from tqdm.notebook import tqdm

video_paths = sv.list_files_with_extensions(
    directory=VIDEO_DIR_PATH,
    extensions=["mov", "mp4"])

TEST_VIDEO_PATHS, TRAIN_VIDEO_PATHS = video_paths[:2], video_paths[2:]

for video_path in tqdm(TRAIN_VIDEO_PATHS):
    video_name = video_path.stem
    image_name_pattern = video_name + "-{:05d}.png"
    with sv.ImageSink(target_dir_path=IMAGE_DIR_PATH, image_name_pattern=image_name_pattern) as sink:
        for image in sv.get_video_frames_generator(source_path=str(video_path), stride=FRAME_STRIDE):
            sink.save_image(image=image)
# Out:
#   0%|          | 0/6 [00:00<?, ?it/s]

# %% [markdown]
# ### Display image sample
#
# **NOTE:** Before we start building a model with autodistill, let's make sure we have everything we need.

# %%
import supervision as sv

image_paths = sv.list_files_with_extensions(
    directory=IMAGE_DIR_PATH,
    extensions=["png", "jpg", "jpg"])

print('image count:', len(image_paths))
# Out:
# image count: 158

# %% [markdown]
# **NOTE:** We can also plot sample of our image dataset.

# %%
IMAGE_DIR_PATH = f"{HOME}/images"
SAMPLE_SIZE = 16
SAMPLE_GRID_SIZE = (4, 4)
SAMPLE_PLOT_SIZE = (16, 10)

# %%
import cv2
import supervision as sv

titles = [
    image_path.stem
    for image_path
    in image_paths[:SAMPLE_SIZE]]
images = [
    cv2.imread(str(image_path))
    for image_path
    in image_paths[:SAMPLE_SIZE]]

sv.plot_images_grid(images=images, titles=titles, grid_size=SAMPLE_GRID_SIZE, size=SAMPLE_PLOT_SIZE)

# %% [markdown]
# ## 🏷️ Autolabel dataset

# %% [markdown]
# ### Define ontology
#
# **Ontology** - an Ontology defines how your Base Model is prompted, what your Dataset will describe, and what your Target Model will predict. A simple Ontology is the CaptionOntology which prompts a Base Model with text captions and maps them to class names. Other Ontologies may, for instance, use a CLIP vector or example images instead of a text caption.

# %%
from autodistill.detection import CaptionOntology

ontology=CaptionOntology({
    "milk bottle": "bottle",
    "blue cap": "cap"
})

# %% [markdown]
# ### Initiate base model and autolabel
#
# **Base Model** - A Base Model is a large foundation model that knows a lot about a lot. Base models are often multimodal and can perform many tasks. They're large, slow, and expensive. Examples of Base Models are GroundedSAM and GPT-4's upcoming multimodal variant. We use a Base Model (along with unlabeled input data and an Ontology) to create a Dataset.

# %%
DATASET_DIR_PATH = f"{HOME}/dataset"

# %% [markdown]
# **NOTE:** Base Models are slow... Make yourself a coffee, autolabeing may take a while. ☕

# %%
from autodistill_grounded_sam import GroundedSAM

base_model = GroundedSAM(ontology=ontology)
dataset = base_model.label(
    input_folder=IMAGE_DIR_PATH,
    extension=".png",
    output_folder=DATASET_DIR_PATH)
# Out:
# Importing from timm.models.layers is deprecated, please import via timm.layers
# trying to load grounding dino directly
# downloading dino model weights
# torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3595.)
# final text_encoder_type: bert-base-uncased
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/440M [00:00<?, ?B/s]
# You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# Labeling /content/images/milk-video-2-00010.png:   0%|          | 0/158 [00:00<?, ?it/s]The `device` argument is deprecated and will be removed in v5 of Transformers.
# torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
# None of the inputs have requires_grad=True. Gradients will be None
# `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
# Labeling /content/images/milk-video-6-00016.png: 100%|██████████| 158/158 [08:57<00:00,  3.40s/it]
# Labeled dataset created - ready for distillation.

# %% [markdown]
# ### Display dataset sample
#
# **Dataset** - a Dataset is a set of auto-labeled data that can be used to train a Target Model. It is the output generated by a Base Model.

# %%
ANNOTATIONS_DIRECTORY_PATH = f"{HOME}/dataset/train/labels"
IMAGES_DIRECTORY_PATH = f"{HOME}/dataset/train/images"
DATA_YAML_PATH = f"{HOME}/dataset/data.yaml"

# %%
import supervision as sv

dataset = sv.DetectionDataset.from_yolo(
    images_directory_path=IMAGES_DIRECTORY_PATH,
    annotations_directory_path=ANNOTATIONS_DIRECTORY_PATH,
    data_yaml_path=DATA_YAML_PATH)

len(dataset)
# Out:
# 126

# %%
import supervision as sv
from pathlib import Path


mask_annotator = sv.MaskAnnotator()
box_annotator = sv.BoxAnnotator()
label_annotator = sv.LabelAnnotator()

images = []
image_names = []
for i, (image_path, image, annotation) in enumerate(dataset):
    if i == SAMPLE_SIZE:
        break
    annotated_image = image.copy()
    annotated_image = mask_annotator.annotate(
        scene=annotated_image, detections=annotation)
    annotated_image = box_annotator.annotate(
        scene=annotated_image, detections=annotation)
    annotated_image = label_annotator.annotate(
        scene=annotated_image, detections=annotation)

    image_names.append(Path(image_path).name)
    images.append(annotated_image)

sv.plot_images_grid(
    images=images,
    titles=image_names,
    grid_size=SAMPLE_GRID_SIZE,
    size=SAMPLE_PLOT_SIZE)

# %% [markdown]
# ## 🔥 Train target model - YOLOv8
#
# **Target Model** - a Target Model is a supervised model that consumes a Dataset and outputs a distilled model that is ready for deployment. Target Models are usually small, fast, and fine-tuned to perform a specific task very well (but they don't generalize well beyond the information described in their Dataset). Examples of Target Models are YOLOv8 and DETR.

# %%
# %cd {HOME}

from autodistill_yolov8 import YOLOv8

target_model = YOLOv8("yolov8n.pt")
target_model.train(DATA_YAML_PATH, epochs=50)
# Out:
# /content
# Downloading https://github.com/ultralytics/assets/releases/download/v0.0.0/yolov8n.pt to yolov8n.pt...
# 100%|██████████| 6.23M/6.23M [00:00<00:00, 90.3MB/s]
# You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# New https://pypi.org/project/ultralytics/8.3.56 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.81 🚀 Python-3.10.12 torch-2.5.1+cu121 CPU
# yolo/engine/trainer: task=detect, mode=train, model=yolov8n.pt, data=/content/dataset/data.yaml, epochs=50, patience=50, batch=16, imgsz=640, save=True, save_period=-1, cache=False, device=cpu, workers=8, project=None, name=None, exist_ok=False, pretrained=False, optimizer=SGD, verbose=True, seed=0, deterministic=True, single_cls=False, image_weights=False, rect=False, cos_lr=False, close_mosaic=0, resume=False, amp=True, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, show=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, vid_stride=1, line_thickness=3, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, boxes=True, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0, cfg=None, v5loader=False, tracker=botsort.yaml, save_dir=runs/detect/train
# Downloading https://ultralytics.com/assets/Arial.ttf to /root/.config/Ultralytics/Arial.ttf...
# 100%|██████████| 755k/755k [00:00<00:00, 19.9MB/s]
# Overriding model.yaml nc=80 with nc=2
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.Conv                  [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.Conv                  [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.C2f                   [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.Conv                  [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.C2f                   [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.Conv                  [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.C2f                   [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.Conv                  [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.C2f                   [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.SPPF                  [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.Concat                [1]
#  12                  -1  1    148224  ultralytics.nn.modules.C2f                   [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.Concat                [1]
#  15                  -1  1     37248  ultralytics.nn.modules.C2f                   [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.Conv                  [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.Concat                [1]
#  18                  -1  1    123648  ultralytics.nn.modules.C2f                   [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.Conv                  [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.Concat                [1]
#  21                  -1  1    493056  ultralytics.nn.modules.C2f                   [384, 256, 1]
#  22        [15, 18, 21]  1    751702  ultralytics.nn.modules.Detect                [2, [64, 128, 256]]
# Model summary: 225 layers, 3011238 parameters, 3011222 gradients, 8.2 GFLOPs
#
# Transferred 319/355 items from pretrained weights
# TensorBoard: Start with 'tensorboard --logdir runs/detect/train', view at http://localhost:6006/
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
#  ··········
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# Tracking run with wandb version 0.19.1
# Run data is saved locally in <code>/content/wandb/run-20250101_080803-hjyaodrn</code>
# Syncing run <strong><a href='https://wandb.ai/1410732001-none/YOLOv8/runs/hjyaodrn' target="_blank">ethereal-field-1</a></strong> to <a href='https://wandb.ai/1410732001-none/YOLOv8' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/1410732001-none/YOLOv8' target="_blank">https://wandb.ai/1410732001-none/YOLOv8</a>
#  View run at <a href='https://wandb.ai/1410732001-none/YOLOv8/runs/hjyaodrn' target="_blank">https://wandb.ai/1410732001-none/YOLOv8/runs/hjyaodrn</a>
# `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
# optimizer: SGD(lr=0.01) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias
# train: Scanning /content/dataset/train/labels... 126 images, 0 backgrounds, 0 corrupt: 100%|██████████| 126/126 [00:00<00:00, 387.42it/s]
# train: New cache created: /content/dataset/train/labels.cache
# A new version of Albumentations is available: 1.4.24 (you have 1.4.20). Upgrade using: pip install -U albumentations. To disable automatic update checks, set the environment variable NO_ALBUMENTATIONS_UPDATE to 1.
# Got processor for bboxes, but no transform to process it.
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, num_output_channels=3, method='weighted_average'), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Scanning /content/dataset/valid/labels... 32 images, 0 backgrounds, 0 corrupt: 100%|██████████| 32/32 [00:00<00:00, 340.08it/s]
# val: WARNING ⚠️ /content/dataset/valid/images/milk-video-1-00016.jpg: 1 duplicate labels removed
# val: New cache created: /content/dataset/valid/labels.cache
# Plotting labels to runs/detect/train/labels.jpg...
# Image sizes 640 train, 640 val
# Using 0 dataloader workers
# Logging results to runs/detect/train
# Starting training for 50 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#   0%|          | 0/8 [00:00<?, ?it/s]`torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#        1/50       8.1G      1.271      3.556      1.266        140        640: 100%|██████████| 8/8 [01:24<00:00, 10.62s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:05<00:00,  5.52s/it]
#                    all         32        141    0.00731      0.507      0.101     0.0853
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/50      3.43G     0.7007      3.077     0.9916        141        640: 100%|██████████| 8/8 [01:22<00:00, 10.26s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:04<00:00,  4.46s/it]
#                    all         32        141    0.00754      0.512        0.2      0.173
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/50      3.43G     0.6276      1.974     0.9258        110        640: 100%|██████████| 8/8 [01:23<00:00, 10.42s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:04<00:00,  4.42s/it]
#                    all         32        141      0.305      0.425      0.399      0.323
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/50      3.43G     0.6455      1.307     0.9099        128        640: 100%|██████████| 8/8 [01:21<00:00, 10.18s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:04<00:00,  4.42s/it]
#                    all         32        141      0.976      0.296      0.497      0.415
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/50      3.43G     0.6237      1.146     0.8922        123        640: 100%|██████████| 8/8 [01:22<00:00, 10.25s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:05<00:00,  5.23s/it]
#                    all         32        141          1      0.177      0.493       0.44
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/50      3.43G     0.6172      1.078     0.8886        144        640: 100%|██████████| 8/8 [01:20<00:00, 10.11s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:05<00:00,  5.41s/it]
#                    all         32        141          1      0.123      0.479      0.429
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/50      3.43G     0.6078      1.016     0.8938        132        640: 100%|██████████| 8/8 [01:19<00:00,  9.98s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:05<00:00,  5.53s/it]
#                    all         32        141          1      0.178      0.604      0.525
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/50      3.43G     0.6276     0.9583     0.8795        133        640: 100%|██████████| 8/8 [01:19<00:00,  9.94s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:05<00:00,  5.55s/it]
#                    all         32        141          1      0.295      0.731      0.626
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/50      3.43G     0.6302     0.9348     0.8894        138        640: 100%|██████████| 8/8 [01:19<00:00,  9.96s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:05<00:00,  5.21s/it]
#                    all         32        141      0.971      0.499      0.863      0.731
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/50      3.43G     0.6962     0.9395     0.9034        134        640: 100%|██████████| 8/8 [01:19<00:00,  9.96s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:05<00:00,  5.06s/it]
#                    all         32        141      0.975      0.404      0.795      0.666
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/50      3.43G      0.711     0.9591     0.8978        101        640: 100%|██████████| 8/8 [01:19<00:00,  9.95s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:04<00:00,  4.94s/it]
#                    all         32        141      0.847      0.535      0.782      0.668
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/50      3.43G     0.6545     0.9358     0.8809        100        640: 100%|██████████| 8/8 [01:19<00:00,  9.91s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:05<00:00,  5.22s/it]
#                    all         32        141      0.529      0.456      0.694      0.557
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/50      3.43G     0.6897     0.9398     0.8804        134        640: 100%|██████████| 8/8 [01:22<00:00, 10.36s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:04<00:00,  4.44s/it]
#                    all         32        141      0.531      0.517      0.707      0.571
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/50      3.43G     0.6559      1.019     0.8891        109        640: 100%|██████████| 8/8 [01:20<00:00, 10.07s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:04<00:00,  4.41s/it]
#                    all         32        141      0.615      0.612      0.719      0.611
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/50      3.43G     0.6652     0.9181     0.8928        120        640: 100%|██████████| 8/8 [01:20<00:00, 10.05s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:04<00:00,  4.44s/it]
#                    all         32        141      0.831       0.88      0.882      0.714
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       16/50      3.43G     0.6238     0.8994     0.8798        162        640: 100%|██████████| 8/8 [01:20<00:00, 10.08s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:04<00:00,  4.42s/it]
#                    all         32        141      0.862       0.86      0.907       0.75
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       17/50      3.43G     0.5991     0.8384     0.8713        101        640: 100%|██████████| 8/8 [01:20<00:00, 10.01s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:04<00:00,  4.47s/it]
#                    all         32        141      0.831      0.905      0.897      0.707
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       18/50      3.43G     0.6074     0.8697     0.8778        134        640: 100%|██████████| 8/8 [01:20<00:00, 10.06s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:04<00:00,  4.62s/it]
#                    all         32        141      0.853      0.809      0.883      0.747
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       19/50      3.43G     0.5855     0.8233     0.8872        158        640: 100%|██████████| 8/8 [01:20<00:00, 10.08s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:05<00:00,  5.05s/it]
#                    all         32        141      0.851      0.898       0.92      0.781
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       20/50      3.43G     0.5981     0.7975     0.8704        138        640: 100%|██████████| 8/8 [01:20<00:00, 10.12s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:05<00:00,  5.58s/it]
#                    all         32        141      0.863      0.915      0.926      0.805
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       21/50      3.43G     0.6058     0.8165      0.869        140        640: 100%|██████████| 8/8 [01:20<00:00, 10.08s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:05<00:00,  5.39s/it]
#                    all         32        141      0.828      0.905      0.922      0.765
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       22/50      3.43G     0.5476     0.7713     0.8728        132        640: 100%|██████████| 8/8 [01:19<00:00,  9.93s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:05<00:00,  5.22s/it]
#                    all         32        141      0.778      0.912      0.916      0.782
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       23/50      3.43G     0.5367     0.7692     0.8644        109        640: 100%|██████████| 8/8 [01:19<00:00,  9.97s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:04<00:00,  5.00s/it]
#                    all         32        141      0.856      0.882      0.921      0.786
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       24/50      3.43G     0.5278     0.7468     0.8674        140        640: 100%|██████████| 8/8 [01:20<00:00, 10.05s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:04<00:00,  4.65s/it]
#                    all         32        141      0.851      0.896      0.925      0.815
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       25/50      3.43G     0.5469     0.7141     0.8665        144        640: 100%|██████████| 8/8 [01:21<00:00, 10.20s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:05<00:00,  5.07s/it]
#                    all         32        141      0.835      0.924      0.934      0.797
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       26/50      3.43G      0.525     0.7386     0.8602        136        640: 100%|██████████| 8/8 [01:21<00:00, 10.25s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:04<00:00,  4.42s/it]
#                    all         32        141      0.834      0.912      0.938      0.799
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       27/50      3.43G     0.5185     0.7116      0.853        115        640: 100%|██████████| 8/8 [01:21<00:00, 10.16s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:04<00:00,  4.49s/it]
#                    all         32        141      0.851      0.907       0.93      0.808
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       28/50      3.43G     0.5086     0.7042     0.8549        124        640: 100%|██████████| 8/8 [01:22<00:00, 10.36s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:05<00:00,  5.22s/it]
#                    all         32        141      0.888       0.88      0.936      0.814
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       29/50      3.43G     0.4844     0.6835     0.8615        139        640: 100%|██████████| 8/8 [01:22<00:00, 10.32s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:05<00:00,  5.63s/it]
#                    all         32        141      0.863      0.902      0.942      0.827
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       30/50      3.43G     0.4924     0.6666     0.8576        131        640: 100%|██████████| 8/8 [01:21<00:00, 10.24s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:04<00:00,  4.61s/it]
#                    all         32        141      0.932      0.848      0.939       0.83
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       31/50      3.43G     0.4677     0.6639     0.8565        141        640: 100%|██████████| 8/8 [01:22<00:00, 10.32s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:04<00:00,  4.48s/it]
#                    all         32        141      0.865      0.907      0.942      0.822
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       32/50      3.43G     0.4494      0.648      0.846        124        640: 100%|██████████| 8/8 [01:22<00:00, 10.36s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:04<00:00,  4.49s/it]
#                    all         32        141      0.861      0.914      0.946      0.826
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       33/50      3.43G     0.4542     0.6448      0.848        154        640: 100%|██████████| 8/8 [01:22<00:00, 10.37s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:04<00:00,  4.68s/it]
#                    all         32        141      0.848      0.931      0.945      0.843
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       34/50      3.43G     0.4328     0.6153     0.8454        138        640: 100%|██████████| 8/8 [01:22<00:00, 10.29s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:05<00:00,  5.60s/it]
#                    all         32        141      0.867      0.936      0.945      0.839
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       35/50      3.43G     0.4336     0.6654      0.863        149        640: 100%|██████████| 8/8 [01:21<00:00, 10.21s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:05<00:00,  5.25s/it]
#                    all         32        141      0.869      0.921      0.948      0.856
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       36/50      3.43G     0.4258     0.6548     0.8416        110        640: 100%|██████████| 8/8 [01:23<00:00, 10.43s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:04<00:00,  4.43s/it]
#                    all         32        141      0.852      0.941       0.94      0.841
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       37/50      3.43G     0.4108     0.6344      0.847        100        640: 100%|██████████| 8/8 [01:22<00:00, 10.37s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:04<00:00,  4.47s/it]
#                    all         32        141      0.873      0.895      0.937      0.849
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       38/50      3.43G     0.4236     0.6348     0.8484         95        640: 100%|██████████| 8/8 [01:23<00:00, 10.40s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:04<00:00,  4.97s/it]
#                    all         32        141      0.866      0.913      0.946      0.853
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       39/50      3.43G     0.3898      0.614     0.8428        102        640: 100%|██████████| 8/8 [01:20<00:00, 10.11s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:05<00:00,  5.34s/it]
#                    all         32        141      0.847      0.941      0.951      0.857
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       40/50      3.43G     0.3972     0.6103     0.8505        124        640: 100%|██████████| 8/8 [01:20<00:00, 10.07s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:05<00:00,  5.35s/it]
#                    all         32        141      0.852      0.922      0.948      0.861
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       41/50      3.43G     0.3778     0.5967     0.8294        123        640: 100%|██████████| 8/8 [01:20<00:00, 10.08s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:05<00:00,  5.01s/it]
#                    all         32        141      0.859      0.921      0.944      0.855
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       42/50      3.43G      0.368      0.574     0.8362        164        640: 100%|██████████| 8/8 [01:21<00:00, 10.24s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:04<00:00,  4.52s/it]
#                    all         32        141      0.833      0.949      0.943      0.862
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       43/50      3.43G     0.3787     0.5794     0.8417        118        640: 100%|██████████| 8/8 [01:22<00:00, 10.34s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:04<00:00,  4.64s/it]
#                    all         32        141      0.845      0.929      0.946      0.867
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       44/50      3.43G       0.38     0.5647     0.8505        129        640: 100%|██████████| 8/8 [01:21<00:00, 10.22s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:04<00:00,  4.51s/it]
#                    all         32        141      0.826      0.957      0.946      0.862
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       45/50      3.43G     0.3508     0.5748     0.8288        140        640: 100%|██████████| 8/8 [01:20<00:00, 10.12s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:04<00:00,  4.48s/it]
#                    all         32        141      0.847      0.929      0.949      0.874
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       46/50      3.43G     0.3434     0.5247     0.8199        123        640: 100%|██████████| 8/8 [01:21<00:00, 10.15s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:04<00:00,  4.94s/it]
#                    all         32        141      0.858      0.941      0.948      0.873
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       47/50      3.43G     0.3416     0.5441     0.8281        155        640: 100%|██████████| 8/8 [01:22<00:00, 10.29s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:05<00:00,  5.55s/it]
#                    all         32        141      0.847      0.941      0.951      0.875
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       48/50      3.43G     0.3424     0.5518     0.8419        110        640: 100%|██████████| 8/8 [01:19<00:00,  9.95s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:05<00:00,  5.31s/it]
#                    all         32        141      0.844      0.948      0.944      0.875
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       49/50      3.43G     0.3373     0.5493     0.8303        133        640: 100%|██████████| 8/8 [01:19<00:00,  9.99s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:05<00:00,  5.05s/it]
#                    all         32        141      0.854      0.941      0.942      0.872
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       50/50      3.43G     0.3294     0.5339     0.8311         98        640: 100%|██████████| 8/8 [01:20<00:00, 10.02s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:04<00:00,  4.74s/it]
#                    all         32        141      0.868      0.941       0.94      0.869
#
# 50 epochs completed in 1.203 hours.
# You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# Optimizer stripped from runs/detect/train/weights/last.pt, 6.2MB
# Optimizer stripped from runs/detect/train/weights/best.pt, 6.2MB
#
# Validating runs/detect/train/weights/best.pt...
# Ultralytics YOLOv8.0.81 🚀 Python-3.10.12 torch-2.5.1+cu121 CPU
# You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# Model summary (fused): 168 layers, 3006038 parameters, 0 gradients, 8.1 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:04<00:00,  4.35s/it]
#                    all         32        141      0.851      0.941       0.95      0.875
#                 bottle         32        100      0.901       0.98      0.978       0.93
#                    cap         32         41        0.8      0.902      0.923       0.82
# Speed: 1.3ms preprocess, 92.4ms inference, 0.0ms loss, 4.5ms postprocess per image
# Results saved to runs/detect/train
# You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.

# %%
# Fix intermittent Colab bug. You may not need this.
# NotImplementedError: A UTF-8 locale is required. Got ANSI_X3.4-1968
import locale
locale.getpreferredencoding = lambda: "UTF-8"

# %%
# !ls {HOME}/runs/detect/train/
# Out:
# args.yaml					   P_curve.png	     train_batch1.jpg
# confusion_matrix.png				   PR_curve.png      train_batch2.jpg
# events.out.tfevents.1735718659.bb35e2a2b770.356.0  R_curve.png	     val_batch0_labels.jpg
# F1_curve.png					   results.csv	     val_batch0_pred.jpg
# labels_correlogram.jpg				   results.png	     weights
# labels.jpg					   train_batch0.jpg

# %% [markdown]
# ## ⚖️ Evaluate target model
#
# **NOTE:** As with the regular YOLOv8 training, we can now take a look at artifacts stored in `runs` directory.

# %%
# %cd {HOME}

from IPython.display import Image

Image(filename=f'{HOME}/runs/detect/train/confusion_matrix.png', width=600)
# Out:
# /content

# %%
# %cd {HOME}

from IPython.display import Image

Image(filename=f'{HOME}/runs/detect/train/results.png', width=600)
# Out:
# /content

# %%
# %cd {HOME}

from IPython.display import Image

Image(filename=f'{HOME}/runs/detect/train/val_batch0_pred.jpg', width=600)
# Out:
# /content

# %% [markdown]
# ## 🎬 Run Inference on a video

# %%
INPUT_VIDEO_PATH = TEST_VIDEO_PATHS[0]
OUTPUT_VIDEO_PATH = f"{HOME}/output.mp4"
TRAINED_MODEL_PATH = f"{HOME}/runs/detect/train/weights/best.pt"

# %%
# !yolo predict model={TRAINED_MODEL_PATH} source={INPUT_VIDEO_PATH}
# Out:
# /usr/local/lib/python3.10/dist-packages/ultralytics/nn/tasks.py:357: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(file, map_location='cpu'), file  # load
# 2025-01-01 09:24:15.905545: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-01-01 09:24:15.934788: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-01-01 09:24:15.943823: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Ultralytics YOLOv8.0.81 🚀 Python-3.10.12 torch-2.5.1+cu121 CPU
# Model summary (fused): 168 layers, 3006038 parameters, 0 gradients, 8.1 GFLOPs
#
# video 1/1 (1/140) /content/videos/milk-video-7.mov: 384x640 4 bottles, 101.0ms
# video 1/1 (2/140) /content/videos/milk-video-7.mov: 384x640 5 bottles, 80.9ms
# video 1/1 (3/140) /content/videos/milk-video-7.mov: 384x640 5 bottles, 87.3ms
# video 1/1 (4/140) /content/videos/milk-video-7.mov: 384x640 6 bottles, 83.3ms
# video 1/1 (5/140) /content/videos/milk-video-7.mov: 384x640 4 bottles, 79.9ms
# video 1/1 (6/140) /content/videos/milk-video-7.mov: 384x640 4 bottles, 95.9ms
# video 1/1 (7/140) /content/videos/milk-video-7.mov: 384x640 4 bottles, 84.4ms
# video 1/1 (8/140) /content/videos/milk-video-7.mov: 384x640 4 bottles, 79.2ms
# video 1/1 (9/140) /content/videos/milk-video-7.mov: 384x640 4 bottles, 82.1ms
# video 1/1 (10/140) /content/videos/milk-video-7.mov: 384x640 4 bottles, 82.2ms
# video 1/1 (11/140) /content/videos/milk-video-7.mov: 384x640 4 bottles, 89.4ms
# video 1/1 (12/140) /content/videos/milk-video-7.mov: 384x640 4 bottles, 90.4ms
# video 1/1 (13/140) /content/videos/milk-video-7.mov: 384x640 5 bottles, 83.5ms
# video 1/1 (14/140) /content/videos/milk-video-7.mov: 384x640 4 bottles, 96.6ms
# video 1/1 (15/140) /content/videos/milk-video-7.mov: 384x640 4 bottles, 87.3ms
# video 1/1 (16/140) /content/videos/milk-video-7.mov: 384x640 5 bottles, 83.4ms
# video 1/1 (17/140) /content/videos/milk-video-7.mov: 384x640 4 bottles, 76.2ms
# video 1/1 (18/140) /content/videos/milk-video-7.mov: 384x640 4 bottles, 80.3ms
# video 1/1 (19/140) /content/videos/milk-video-7.mov: 384x640 4 bottles, 84.1ms
# video 1/1 (20/140) /content/videos/milk-video-7.mov: 384x640 4 bottles, 76.0ms
# video 1/1 (21/140) /content/videos/milk-video-7.mov: 384x640 4 bottles, 77.8ms
# video 1/1 (22/140) /content/videos/milk-video-7.mov: 384x640 4 bottles, 78.0ms
# video 1/1 (23/140) /content/videos/milk-video-7.mov: 384x640 4 bottles, 86.3ms
# video 1/1 (24/140) /content/videos/milk-video-7.mov: 384x640 4 bottles, 83.9ms
# video 1/1 (25/140) /content/videos/milk-video-7.mov: 384x640 4 bottles, 77.0ms
# video 1/1 (26/140) /content/videos/milk-video-7.mov: 384x640 4 bottles, 85.4ms
# video 1/1 (27/140) /content/videos/milk-video-7.mov: 384x640 4 bottles, 76.1ms
# video 1/1 (28/140) /content/videos/milk-video-7.mov: 384x640 4 bottles, 85.8ms
# video 1/1 (29/140) /content/videos/milk-video-7.mov: 384x640 4 bottles, 86.9ms
# video 1/1 (30/140) /content/videos/milk-video-7.mov: 384x640 4 bottles, 81.1ms
# video 1/1 (31/140) /content/videos/milk-video-7.mov: 384x640 4 bottles, 82.7ms
# video 1/1 (32/140) /content/videos/milk-video-7.mov: 384x640 4 bottles, 87.0ms
# video 1/1 (33/140) /content/videos/milk-video-7.mov: 384x640 4 bottles, 80.1ms
# video 1/1 (34/140) /content/videos/milk-video-7.mov: 384x640 4 bottles, 80.4ms
# video 1/1 (35/140) /content/videos/milk-video-7.mov: 384x640 4 bottles, 80.0ms
# video 1/1 (36/140) /content/videos/milk-video-7.mov: 384x640 4 bottles, 81.5ms
# video 1/1 (37/140) /content/videos/milk-video-7.mov: 384x640 4 bottles, 82.5ms
# video 1/1 (38/140) /content/videos/milk-video-7.mov: 384x640 4 bottles, 78.9ms
# video 1/1 (39/140) /content/videos/milk-video-7.mov: 384x640 4 bottles, 80.2ms
# video 1/1 (40/140) /content/videos/milk-video-7.mov: 384x640 4 bottles, 94.2ms
# video 1/1 (41/140) /content/videos/milk-video-7.mov: 384x640 4 bottles, 87.0ms
# video 1/1 (42/140) /content/videos/milk-video-7.mov: 384x640 4 bottles, 82.9ms
# video 1/1 (43/140) /content/videos/milk-video-7.mov: 384x640 4 bottles, 83.2ms
# video 1/1 (44/140) /content/videos/milk-video-7.mov: 384x640 4 bottles, 77.2ms
# video 1/1 (45/140) /content/videos/milk-video-7.mov: 384x640 4 bottles, 81.6ms
# video 1/1 (46/140) /content/videos/milk-video-7.mov: 384x640 4 bottles, 85.8ms
# video 1/1 (47/140) /content/videos/milk-video-7.mov: 384x640 4 bottles, 80.6ms
# video 1/1 (48/140) /content/videos/milk-video-7.mov: 384x640 4 bottles, 83.2ms
# video 1/1 (49/140) /content/videos/milk-video-7.mov: 384x640 4 bottles, 99.4ms
# video 1/1 (50/140) /content/videos/milk-video-7.mov: 384x640 4 bottles, 82.1ms
# video 1/1 (51/140) /content/videos/milk-video-7.mov: 384x640 4 bottles, 77.4ms
# video 1/1 (52/140) /content/videos/milk-video-7.mov: 384x640 4 bottles, 81.4ms
# video 1/1 (53/140) /content/videos/milk-video-7.mov: 384x640 4 bottles, 76.3ms
# video 1/1 (54/140) /content/videos/milk-video-7.mov: 384x640 4 bottles, 85.3ms
# video 1/1 (55/140) /content/videos/milk-video-7.mov: 384x640 4 bottles, 82.4ms
# video 1/1 (56/140) /content/videos/milk-video-7.mov: 384x640 4 bottles, 79.9ms
# video 1/1 (57/140) /content/videos/milk-video-7.mov: 384x640 4 bottles, 83.6ms
# video 1/1 (58/140) /content/videos/milk-video-7.mov: 384x640 4 bottles, 82.0ms
# video 1/1 (59/140) /content/videos/milk-video-7.mov: 384x640 4 bottles, 78.8ms
# video 1/1 (60/140) /content/videos/milk-video-7.mov: 384x640 4 bottles, 86.9ms
# video 1/1 (61/140) /content/videos/milk-video-7.mov: 384x640 4 bottles, 116.2ms
# video 1/1 (62/140) /content/videos/milk-video-7.mov: 384x640 4 bottles, 125.2ms
# video 1/1 (63/140) /content/videos/milk-video-7.mov: 384x640 4 bottles, 107.9ms
# video 1/1 (64/140) /content/videos/milk-video-7.mov: 384x640 4 bottles, 108.4ms
# video 1/1 (65/140) /content/videos/milk-video-7.mov: 384x640 4 bottles, 107.3ms
# video 1/1 (66/140) /content/videos/milk-video-7.mov: 384x640 4 bottles, 121.7ms
# video 1/1 (67/140) /content/videos/milk-video-7.mov: 384x640 4 bottles, 121.7ms
# video 1/1 (68/140) /content/videos/milk-video-7.mov: 384x640 4 bottles, 120.4ms
# video 1/1 (69/140) /content/videos/milk-video-7.mov: 384x640 4 bottles, 105.8ms
# video 1/1 (70/140) /content/videos/milk-video-7.mov: 384x640 4 bottles, 115.0ms
# video 1/1 (71/140) /content/videos/milk-video-7.mov: 384x640 4 bottles, 131.1ms
# video 1/1 (72/140) /content/videos/milk-video-7.mov: 384x640 4 bottles, 111.3ms
# video 1/1 (73/140) /content/videos/milk-video-7.mov: 384x640 4 bottles, 112.5ms
# video 1/1 (74/140) /content/videos/milk-video-7.mov: 384x640 4 bottles, 110.6ms
# video 1/1 (75/140) /content/videos/milk-video-7.mov: 384x640 4 bottles, 113.9ms
# video 1/1 (76/140) /content/videos/milk-video-7.mov: 384x640 4 bottles, 119.9ms
# video 1/1 (77/140) /content/videos/milk-video-7.mov: 384x640 4 bottles, 133.4ms
# video 1/1 (78/140) /content/videos/milk-video-7.mov: 384x640 5 bottles, 122.7ms
# video 1/1 (79/140) /content/videos/milk-video-7.mov: 384x640 4 bottles, 110.7ms
# video 1/1 (80/140) /content/videos/milk-video-7.mov: 384x640 4 bottles, 116.5ms
# video 1/1 (81/140) /content/videos/milk-video-7.mov: 384x640 4 bottles, 119.6ms
# video 1/1 (82/140) /content/videos/milk-video-7.mov: 384x640 5 bottles, 126.3ms
# video 1/1 (83/140) /content/videos/milk-video-7.mov: 384x640 4 bottles, 125.1ms
# video 1/1 (84/140) /content/videos/milk-video-7.mov: 384x640 4 bottles, 133.6ms
# video 1/1 (85/140) /content/videos/milk-video-7.mov: 384x640 4 bottles, 132.4ms
# video 1/1 (86/140) /content/videos/milk-video-7.mov: 384x640 4 bottles, 115.5ms
# video 1/1 (87/140) /content/videos/milk-video-7.mov: 384x640 5 bottles, 122.2ms
# video 1/1 (88/140) /content/videos/milk-video-7.mov: 384x640 4 bottles, 85.5ms
# video 1/1 (89/140) /content/videos/milk-video-7.mov: 384x640 4 bottles, 73.3ms
# video 1/1 (90/140) /content/videos/milk-video-7.mov: 384x640 4 bottles, 82.9ms
# video 1/1 (91/140) /content/videos/milk-video-7.mov: 384x640 4 bottles, 87.0ms
# video 1/1 (92/140) /content/videos/milk-video-7.mov: 384x640 4 bottles, 75.3ms
# video 1/1 (93/140) /content/videos/milk-video-7.mov: 384x640 4 bottles, 78.7ms
# video 1/1 (94/140) /content/videos/milk-video-7.mov: 384x640 4 bottles, 80.4ms
# video 1/1 (95/140) /content/videos/milk-video-7.mov: 384x640 4 bottles, 84.9ms
# video 1/1 (96/140) /content/videos/milk-video-7.mov: 384x640 4 bottles, 81.5ms
# video 1/1 (97/140) /content/videos/milk-video-7.mov: 384x640 4 bottles, 83.6ms
# video 1/1 (98/140) /content/videos/milk-video-7.mov: 384x640 4 bottles, 96.2ms
# video 1/1 (99/140) /content/videos/milk-video-7.mov: 384x640 4 bottles, 82.4ms
# video 1/1 (100/140) /content/videos/milk-video-7.mov: 384x640 4 bottles, 84.1ms
# video 1/1 (101/140) /content/videos/milk-video-7.mov: 384x640 4 bottles, 89.8ms
# video 1/1 (102/140) /content/videos/milk-video-7.mov: 384x640 4 bottles, 76.7ms
# video 1/1 (103/140) /content/videos/milk-video-7.mov: 384x640 4 bottles, 81.1ms
# video 1/1 (104/140) /content/videos/milk-video-7.mov: 384x640 4 bottles, 81.9ms
# video 1/1 (105/140) /content/videos/milk-video-7.mov: 384x640 4 bottles, 84.1ms
# video 1/1 (106/140) /content/videos/milk-video-7.mov: 384x640 4 bottles, 79.6ms
# video 1/1 (107/140) /content/videos/milk-video-7.mov: 384x640 4 bottles, 88.6ms
# video 1/1 (108/140) /content/videos/milk-video-7.mov: 384x640 4 bottles, 1 cap, 103.0ms
# video 1/1 (109/140) /content/videos/milk-video-7.mov: 384x640 4 bottles, 1 cap, 77.8ms
# video 1/1 (110/140) /content/videos/milk-video-7.mov: 384x640 4 bottles, 1 cap, 78.0ms
# video 1/1 (111/140) /content/videos/milk-video-7.mov: 384x640 4 bottles, 1 cap, 80.3ms
# video 1/1 (112/140) /content/videos/milk-video-7.mov: 384x640 4 bottles, 84.3ms
# video 1/1 (113/140) /content/videos/milk-video-7.mov: 384x640 4 bottles, 81.7ms
# video 1/1 (114/140) /content/videos/milk-video-7.mov: 384x640 4 bottles, 86.0ms
# video 1/1 (115/140) /content/videos/milk-video-7.mov: 384x640 4 bottles, 86.2ms
# video 1/1 (116/140) /content/videos/milk-video-7.mov: 384x640 4 bottles, 85.8ms
# video 1/1 (117/140) /content/videos/milk-video-7.mov: 384x640 4 bottles, 80.8ms
# video 1/1 (118/140) /content/videos/milk-video-7.mov: 384x640 3 bottles, 81.3ms
# video 1/1 (119/140) /content/videos/milk-video-7.mov: 384x640 3 bottles, 81.2ms
# video 1/1 (120/140) /content/videos/milk-video-7.mov: 384x640 3 bottles, 84.6ms
# video 1/1 (121/140) /content/videos/milk-video-7.mov: 384x640 3 bottles, 88.6ms
# video 1/1 (122/140) /content/videos/milk-video-7.mov: 384x640 3 bottles, 85.9ms
# video 1/1 (123/140) /content/videos/milk-video-7.mov: 384x640 3 bottles, 82.0ms
# video 1/1 (124/140) /content/videos/milk-video-7.mov: 384x640 3 bottles, 92.9ms
# video 1/1 (125/140) /content/videos/milk-video-7.mov: 384x640 3 bottles, 87.5ms
# video 1/1 (126/140) /content/videos/milk-video-7.mov: 384x640 3 bottles, 75.2ms
# video 1/1 (127/140) /content/videos/milk-video-7.mov: 384x640 3 bottles, 76.4ms
# video 1/1 (128/140) /content/videos/milk-video-7.mov: 384x640 3 bottles, 91.6ms
# video 1/1 (129/140) /content/videos/milk-video-7.mov: 384x640 3 bottles, 82.5ms
# video 1/1 (130/140) /content/videos/milk-video-7.mov: 384x640 3 bottles, 83.9ms
# video 1/1 (131/140) /content/videos/milk-video-7.mov: 384x640 3 bottles, 81.4ms
# video 1/1 (132/140) /content/videos/milk-video-7.mov: 384x640 3 bottles, 81.9ms
# video 1/1 (133/140) /content/videos/milk-video-7.mov: 384x640 3 bottles, 87.6ms
# video 1/1 (134/140) /content/videos/milk-video-7.mov: 384x640 3 bottles, 78.7ms
# video 1/1 (135/140) /content/videos/milk-video-7.mov: 384x640 3 bottles, 75.1ms
# video 1/1 (136/140) /content/videos/milk-video-7.mov: 384x640 3 bottles, 78.5ms
# video 1/1 (137/140) /content/videos/milk-video-7.mov: 384x640 3 bottles, 78.5ms
# video 1/1 (138/140) /content/videos/milk-video-7.mov: 384x640 3 bottles, 94.2ms
# video 1/1 (139/140) /content/videos/milk-video-7.mov: 384x640 3 bottles, 92.2ms
# video 1/1 (140/140) /content/videos/milk-video-7.mov: 384x640 3 bottles, 80.7ms
# Speed: 0.8ms preprocess, 90.3ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# Prediction saved as:
prediction_file = f"{HOME}/runs/detect/predict/milk-video-6.mp4"

# %%
# !zip -r wandb.zip wandb
# Out:
#   adding: wandb/ (stored 0%)
#   adding: wandb/latest-run/ (stored 0%)
#   adding: wandb/latest-run/run-hjyaodrn.wandb (deflated 82%)
#   adding: wandb/latest-run/tmp/ (stored 0%)
#   adding: wandb/latest-run/tmp/code/ (stored 0%)
#   adding: wandb/latest-run/files/ (stored 0%)
#   adding: wandb/latest-run/files/requirements.txt (deflated 55%)
#   adding: wandb/latest-run/files/media/ (stored 0%)
#   adding: wandb/latest-run/files/media/images/ (stored 0%)
#   adding: wandb/latest-run/files/media/images/train_batch0_2_ac6d345a77a8cfb56364.jpg (deflated 5%)
#   adding: wandb/latest-run/files/media/images/train_batch2_2_b6f701613cd8e2832c11.jpg (deflated 5%)
#   adding: wandb/latest-run/files/media/images/train_batch1_2_7099eb2b3aca62656b21.jpg (deflated 6%)
#   adding: wandb/latest-run/files/wandb-metadata.json (deflated 50%)
#   adding: wandb/latest-run/files/output.log (deflated 89%)
#   adding: wandb/latest-run/logs/ (stored 0%)
#   adding: wandb/latest-run/logs/debug-core.log (deflated 58%)
#   adding: wandb/latest-run/logs/debug-internal.log (deflated 82%)
#   adding: wandb/latest-run/logs/debug.log (deflated 79%)
#   adding: wandb/debug-internal.log (deflated 82%)
#   adding: wandb/debug.log (deflated 79%)
#   adding: wandb/run-20250101_080803-hjyaodrn/ (stored 0%)
#   adding: wandb/run-20250101_080803-hjyaodrn/run-hjyaodrn.wandb (deflated 82%)
#   adding: wandb/run-20250101_080803-hjyaodrn/tmp/ (stored 0%)
#   adding: wandb/run-20250101_080803-hjyaodrn/tmp/code/ (stored 0%)
#   adding: wandb/run-20250101_080803-hjyaodrn/files/ (stored 0%)
#   adding: wandb/run-20250101_080803-hjyaodrn/files/requirements.txt (deflated 55%)
#   adding: wandb/run-20250101_080803-hjyaodrn/files/media/ (stored 0%)
#   adding: wandb/run-20250101_080803-hjyaodrn/files/media/images/ (stored 0%)
#   adding: wandb/run-20250101_080803-hjyaodrn/files/media/images/train_batch0_2_ac6d345a77a8cfb56364.jpg (deflated 5%)
#   adding: wandb/run-20250101_080803-hjyaodrn/files/media/images/train_batch2_2_b6f701613cd8e2832c11.jpg (deflated 5%)
#   adding: wandb/run-20250101_080803-hjyaodrn/files/media/images/train_batch1_2_7099eb2b3aca62656b21.jpg (deflated 6%)
#   adding: wandb/run-20250101_080803-hjyaodrn/files/wandb-metadata.json (deflated 50%)
#   adding: wandb/run-20250101_080803-hjyaodrn/files/output.log (deflated 89%)
#   adding: wandb/run-20250101_080803-hjyaodrn/logs/ (stored 0%)
#   adding: wandb/run-20250101_080803-hjyaodrn/logs/debug-core.log (deflated 58%)
#   adding: wandb/run-20250101_080803-hjyaodrn/logs/debug-internal.log (deflated 82%)
#   adding: wandb/run-20250101_080803-hjyaodrn/logs/debug.log (deflated 79%)

# %% [markdown]
# ## Upload dataset and model to Roboflow

# %% [markdown]
# coming soon...

# %% [markdown]
#   # 🏆 Congratulations
#
# ### Learning Resources
#
# Roboflow has produced many resources that you may find interesting as you advance your knowledge of computer vision:
#
# - [Roboflow Notebooks](https://github.com/roboflow/notebooks): A repository of over 20 notebooks that walk through how to train custom models with a range of model types, from YOLOv7 to SegFormer.
# - [Roboflow YouTube](https://www.youtube.com/c/Roboflow): Our library of videos featuring deep dives into the latest in computer vision, detailed tutorials that accompany our notebooks, and more.
# - [Roboflow Discuss](https://discuss.roboflow.com/): Have a question about how to do something on Roboflow? Ask your question on our discussion forum.
# - [Roboflow Models](https://roboflow.com): Learn about state-of-the-art models and their performance. Find links and tutorials to guide your learning.
#
# ### Convert data formats
#
# Roboflow provides free utilities to convert data between dozens of popular computer vision formats. Check out [Roboflow Formats](https://roboflow.com/formats) to find tutorials on how to convert data between formats in a few clicks.
#
# ### Connect computer vision to your project logic
#
# [Roboflow Templates](https://roboflow.com/templates) is a public gallery of code snippets that you can use to connect computer vision to your project logic. Code snippets range from sending emails after inference to measuring object distance between detections.
